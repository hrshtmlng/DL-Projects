# %% [markdown]
# <a href="https://colab.research.google.com/github/hrshtmlng/DL-Projects/blob/main/ANN_Churn_Rate_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("blastchar/telco-customer-churn")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/telco-customer-churn

# %%
import pandas as pd
import os

# Load the CSV file
df = pd.read_csv(os.path.join(path, 'WA_Fn-UseC_-Telco-Customer-Churn.csv'))
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.drop('customerID',axis=1,inplace=True)
df['TotalCharges'] =pd.to_numeric(df['TotalCharges'],errors='coerce')
df.dropna(inplace=True)
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges  \
# 0              Yes           Electronic check           29.85         29.85
# 1               No               Mailed check           56.95       1889.50
# 2              Yes               Mailed check           53.85        108.15
# 3               No  Bank transfer (automatic)           42.30       1840.75
# 4              Yes           Electronic check           70.70        151.65
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %%
df['Churn'] = df['Churn'].map({'Yes':1,'No':0})

# %%
from sklearn.preprocessing import LabelEncoder
binary_cols = ['gender','Partner','Dependents','PhoneService','PaperlessBilling']
le = LabelEncoder()
for col in binary_cols:
  df[col] = le.fit_transform(df[col])

# %%
df = pd.get_dummies(df,columns=[
    'MultipleLines','InternetService','OnlineSecurity','OnlineBackup',
    'DeviceProtection','TechSupport','StreamingTV','StreamingMovies',
    'Contract','PaymentMethod'],drop_first=True)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

X = df.drop('Churn',axis=1)
y = df['Churn']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled,y, test_size=0.2,random_state=42)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# %%
model = models.Sequential([
    layers.Dense(32,activation='relu',input_shape=(X_train.shape[1],)),
    layers.Dense(16,activation='relu'),
    layers.Dense(1,activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

history = model.fit(X_train,y_train,epochs=50,batch_size=32,validation_split=0.2)
# Out:
# Epoch 1/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5703 - loss: 0.6722 - val_accuracy: 0.7867 - val_loss: 0.4419
# Epoch 2/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7980 - loss: 0.4371 - val_accuracy: 0.8098 - val_loss: 0.4121
# Epoch 3/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7947 - loss: 0.4243 - val_accuracy: 0.8169 - val_loss: 0.4082
# Epoch 4/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8043 - loss: 0.4061 - val_accuracy: 0.8213 - val_loss: 0.4035
# Epoch 5/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8025 - loss: 0.4161 - val_accuracy: 0.8178 - val_loss: 0.4035
# Epoch 6/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8028 - loss: 0.4148 - val_accuracy: 0.8160 - val_loss: 0.4018
# Epoch 7/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8022 - loss: 0.4089 - val_accuracy: 0.8169 - val_loss: 0.4057
# Epoch 8/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7955 - loss: 0.4174 - val_accuracy: 0.8196 - val_loss: 0.4002
# Epoch 9/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8030 - loss: 0.4095 - val_accuracy: 0.8187 - val_loss: 0.4001
# Epoch 10/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8065 - loss: 0.4091 - val_accuracy: 0.8169 - val_loss: 0.4015
# Epoch 11/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8105 - loss: 0.4012 - val_accuracy: 0.8213 - val_loss: 0.4028
# Epoch 12/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8172 - loss: 0.3955 - val_accuracy: 0.8169 - val_loss: 0.4011
# Epoch 13/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8192 - loss: 0.3856 - val_accuracy: 0.8133 - val_loss: 0.3990
# Epoch 14/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8104 - loss: 0.3974 - val_accuracy: 0.8098 - val_loss: 0.4005
# Epoch 15/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8237 - loss: 0.3931 - val_accuracy: 0.8124 - val_loss: 0.3998
# Epoch 16/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8216 - loss: 0.3810 - val_accuracy: 0.8124 - val_loss: 0.4016
# Epoch 17/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8171 - loss: 0.3991 - val_accuracy: 0.8116 - val_loss: 0.4027
# Epoch 18/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8192 - loss: 0.3831 - val_accuracy: 0.8142 - val_loss: 0.4033
# Epoch 19/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8275 - loss: 0.3818 - val_accuracy: 0.8071 - val_loss: 0.4033
# Epoch 20/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8238 - loss: 0.3762 - val_accuracy: 0.8062 - val_loss: 0.4058
# Epoch 21/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8273 - loss: 0.3829 - val_accuracy: 0.8098 - val_loss: 0.4046
# Epoch 22/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8244 - loss: 0.3801 - val_accuracy: 0.8062 - val_loss: 0.4106
# Epoch 23/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8329 - loss: 0.3740 - val_accuracy: 0.8107 - val_loss: 0.4072
# Epoch 24/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8207 - loss: 0.3801 - val_accuracy: 0.8080 - val_loss: 0.4090
# Epoch 25/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8167 - loss: 0.3753 - val_accuracy: 0.7991 - val_loss: 0.4129
# Epoch 26/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8362 - loss: 0.3639 - val_accuracy: 0.8044 - val_loss: 0.4110
# Epoch 27/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8329 - loss: 0.3676 - val_accuracy: 0.8027 - val_loss: 0.4101
# Epoch 28/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8301 - loss: 0.3700 - val_accuracy: 0.8018 - val_loss: 0.4122
# Epoch 29/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8287 - loss: 0.3746 - val_accuracy: 0.7982 - val_loss: 0.4125
# Epoch 30/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8355 - loss: 0.3615 - val_accuracy: 0.7982 - val_loss: 0.4135
# Epoch 31/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8205 - loss: 0.3796 - val_accuracy: 0.7991 - val_loss: 0.4137
# Epoch 32/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8321 - loss: 0.3517 - val_accuracy: 0.7964 - val_loss: 0.4173
# Epoch 33/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8313 - loss: 0.3528 - val_accuracy: 0.8027 - val_loss: 0.4179
# Epoch 34/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8296 - loss: 0.3585 - val_accuracy: 0.8009 - val_loss: 0.4198
# Epoch 35/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8387 - loss: 0.3592 - val_accuracy: 0.7964 - val_loss: 0.4193
# Epoch 36/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8425 - loss: 0.3462 - val_accuracy: 0.7982 - val_loss: 0.4184
# Epoch 37/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8407 - loss: 0.3500 - val_accuracy: 0.7947 - val_loss: 0.4243
# Epoch 38/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8402 - loss: 0.3533 - val_accuracy: 0.7964 - val_loss: 0.4242
# Epoch 39/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8385 - loss: 0.3450 - val_accuracy: 0.8009 - val_loss: 0.4216
# Epoch 40/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8428 - loss: 0.3448 - val_accuracy: 0.7956 - val_loss: 0.4337
# Epoch 41/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8240 - loss: 0.3673 - val_accuracy: 0.8036 - val_loss: 0.4286
# Epoch 42/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8362 - loss: 0.3608 - val_accuracy: 0.7956 - val_loss: 0.4302
# Epoch 43/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8367 - loss: 0.3500 - val_accuracy: 0.7947 - val_loss: 0.4363
# Epoch 44/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8506 - loss: 0.3417 - val_accuracy: 0.8000 - val_loss: 0.4311
# Epoch 45/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8348 - loss: 0.3522 - val_accuracy: 0.7991 - val_loss: 0.4323
# Epoch 46/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8366 - loss: 0.3445 - val_accuracy: 0.7858 - val_loss: 0.4373
# Epoch 47/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8457 - loss: 0.3403 - val_accuracy: 0.8000 - val_loss: 0.4332
# Epoch 48/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8373 - loss: 0.3421 - val_accuracy: 0.7902 - val_loss: 0.4383
# Epoch 49/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8389 - loss: 0.3385 - val_accuracy: 0.7947 - val_loss: 0.4419
# Epoch 50/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8471 - loss: 0.3310 - val_accuracy: 0.7938 - val_loss: 0.4386

# %%
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report

y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int)

print("Accuracy:",accuracy_score(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Classification Report:\n",classification_report(y_test,y_pred))
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Accuracy: 0.767590618336887
# Confusion Matrix:
#  [[909 124]
#  [203 171]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85      1033
#            1       0.58      0.46      0.51       374
#
#     accuracy                           0.77      1407
#    macro avg       0.70      0.67      0.68      1407
# weighted avg       0.75      0.77      0.76      1407

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'],label='Train Accuracy')
plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
plt.title('Model Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
